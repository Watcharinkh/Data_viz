# %% [markdown]
# <a href="https://colab.research.google.com/github/Watcharinkh/Data_viz/blob/main/Q4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_excel = pd.read_excel('passenger-covid19.xlsx',sheet_name=1)
data_excel.head()
# Out:
#   ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-13 00:00:00 2021-03-14 00:00:00
# 0     ขนคน (คน)          ทางบก  ...             51204.0             58371.0
# 1     ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 2     ขนคน (คน)          ทางบก  ...             11373.0             12455.0
# 3    ขนคน (คัน)          ทางบก  ...            940739.0            870772.0
# 4    ขนคน (คัน)          ทางบก  ...           1348121.0           1211478.0
#
# [5 rows x 445 columns]

# %%
eight_row = data_excel.iloc[3:7,:]
eight_row
# Out:
#   ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-13 00:00:00 2021-03-14 00:00:00
# 3    ขนคน (คัน)          ทางบก  ...            940739.0            870772.0
# 4    ขนคน (คัน)          ทางบก  ...           1348121.0           1211478.0
# 5    ขนคน (คัน)          ทางบก  ...           1305116.0           1192083.0
# 6    ขนคน (คัน)          ทางบก  ...           1090319.0           1045273.0
#
# [4 rows x 445 columns]
